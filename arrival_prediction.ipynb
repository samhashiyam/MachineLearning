# %% [markdown]
# <a href="https://colab.research.google.com/github/samhashiyam/MachineLearning/blob/main/arrival_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/MyDrive/DSGP/monthlyarrivals.xlsx')

# %%
#Clean column names
df.columns = df.columns.str.strip()

#Remove commas inside numbers
df = df.replace(",", "", regex=True)


df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         1056 non-null   int64
#  1   Month        1056 non-null   object
#  2   Nationality  1056 non-null   object
#  3   Arrivals     1056 non-null   int64
#  4   Avg_Stay     1056 non-null   float64
#  5   Revenue_USD  1056 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 49.6+ KB

# %%
df.shape
# Out:
# (1056, 6)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Nationality', 'Arrivals', 'Avg_Stay', 'Revenue_USD'], dtype='object')

# %%
df.dtypes
# Out:
# Year             int64
# Month           object
# Nationality     object
# Arrivals         int64
# Avg_Stay       float64
# Revenue_USD    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Year           0
# Month          0
# Nationality    0
# Arrivals       0
# Avg_Stay       0
# Revenue_USD    0
# dtype: int64

# %%
#Encode months
month_map = {
    "January":1, "February":2, "March":3, "April":4,
    "May":5, "June":6, "July":7, "August":8,
    "September":9, "October":10, "November":11, "December":12
}

df["Month_Num"] = df["Month"].map(month_map)

# %%
#Label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Nationality_Enc"] = le.fit_transform(df["Nationality"])

# %%
df.head()
# Out:
#    Year    Month         Nationality  Arrivals  Avg_Stay  Revenue_USD  \
# 0  2025  January               India     45496       6.8   58310242.0
# 1  2025  January  Russian Federation     37914      12.5   89335013.0
# 2  2025  January      United Kingdom     20220      13.2   50311716.0
# 3  2025  January             Germany     17693      14.2   47358358.0
# 4  2025  January               China     15165       8.5   24300108.0
#
#    Month_Num  Nationality_Enc
# 0          1                6
# 1          1               18
# 2          1               24
# 3          1                5
# 4          1                3

# %%
#Time index-creates a continuous numeric timeline
df["Time_Index"] = (df["Year"] - df["Year"].min()) * 12 + df["Month_Num"]

# %%
#Lag feature-arrival from prev months for same nationality
df = df.sort_values(["Nationality", "Year", "Month_Num"])

df["Lag_1"] = df.groupby("Nationality")["Arrivals"].shift(1)

# %%
#Rolling average-avg over prev 3 months
df["Rolling_3"] = (
    df.groupby("Nationality")["Arrivals"]
    .transform(lambda x: x.shift(1).rolling(window=3).mean())
)

# %%
#Handle NaNs created by lags
df_model = df.dropna().reset_index(drop=True)
